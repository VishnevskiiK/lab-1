# %% [markdown]
# #Задача 1
# Написать функцию на вход которой подается строка, состоящая из латинских букв.
# Функция должна вернуть количество гласных букв (a, e, i, o, u) в этой строке. Написать тесты для кода

# %%
def func1(string):
    abc = 'aeiou'
    cnt = 0
    for i in abc:
        cnt += string.count(i)
    return cnt
test_list = [
    'qwerty',
    'aaabbbccc',
    'pooooptptptptpgpgpfpgfdgkl;sdfagiasgjafhgharghareljkgha;']
for i in test_list:
    print(func1(i))
# Out:
# 1
# 3
# 12

# %% [markdown]
# # Задача 2
# Написать функцию на вход, которой подается строка. Функция должна вернуть true, если
# каждый символ в строке встречается только 1 раз, иначе должна вернуть false. Написать тесты для кода

# %%
# Your code goes here
def func2(n):
    return sorted(list(n)) == sorted(list(set(n)))
test_list = [
    'qwerty',
    'popopopopop',
    'lkjhgfdsaqwerty']
for i in test_list:
    print(func2(i))
# Out:
# True
# False
# True

# %% [markdown]
# # Задача 3
# Написать функцию, которая принимает положительное число и возвращает количество
# бит равных 1 в этом числе. Написать тесты для кода

# %%
# Your code goes here
def func3(n):
    return bin(n)[2:].count('1')
test_list = [12, 3, 45, 33]
for i in test_list:
    print(bin(i)[2:], func3(i))
# Out:
# 1100 2
# 11 2
# 101101 4
# 100001 2

# %% [markdown]
# # Задача 4
# Написать функцию, которая принимает положительное число. Функция должна вернуть то,
# сколько раз необходимо перемножать цифры числа или результат перемножения, чтобы
# получилось число состоящее из одной цифры.
# Например, для входного числа:
# · 39 функция должна вернуть 3, так как 3*9=27 => 2*7=14 => 1*4=4
# · 4 функция должна вернуть 0, так как число уже состоит из одной цифры
# · 999 функция должна вернуть 4, так как 9*9*9=729 => 7*2*9=126 => 1*2*6=12 =>
# 1*2=2. Написать тесты для кода

# %%
def magic(n):
    cnt = 0
    while n > 10:
        integer_list = map(int, list(str(n)))
        umnozenie = 1
        for i in integer_list: umnozenie *= i
        n = umnozenie
        cnt += 1
    return cnt
test_list = [39, 40, 10, 12]
for i in test_list:print(magic(i))
# Out:
# 3
# 1
# 0
# 1

# %% [markdown]
# # Задача 5
# Написать функцию, которая принимает два целочисленных вектора одинаковой длины и
# возвращает среднеквадратическое отклонение двух векторов. Написать тесты для кода

# %%
def mse(pred, true):
    return 1/len(pred) * sum( (i1 - i2)**2 for i1, i2 in zip(pred, true))
print(mse([1, 2, 3], [2, 3, 4]))
print(mse([1, 3, 3], [2, 9, 4]))
print(mse([6, 2, 4], [2, 3, 2]))
# Out:
# 1.0
# 12.666666666666666
# 7.0

# %% [markdown]
# # Задача 6
# Написать функцию, принимающая целое положительное число. Функция должна вернуть
# строку вида “(n1**p1)(n2**p2)…(nk**pk)” представляющая разложение числа на простые
# множители (если pi == 1, то выводить только ni).
# Например, для числа 86240 функция должна вернуть “(2**5)(5)(7**2)(11)”. Написать тесты для кода

# %%
def is_simple(n):
    for i in range(1, int(n**0.5)+1):
        if n%i == 0 and i!=1:
            return 0
    return 1
def func6(n):
    simp_int_list = [i for i in range(1, n+1) if is_simple(i)][1:]
    result_list = []
    for i in simp_int_list:
        while n%i == 0:
            result_list.append(i)
            n //= i
    result = ''
    for i in sorted(set(result_list)):
        result += f'({i}**{result_list.count(i)})'
    return result.replace('^1', '')
test_list = [
    86240,
    2*2*2*2*11*11,
    2*2*2,
    39856,
    737735
]
for i in test_list:
    print(func6(i))
# Out:
# (2**5)(5**1)(7**2)(11**1)
# (2**4)(11**2)
# (2**3)
# (2**4)(47**1)(53**1)
# (5**1)(147547**1)

# %% [markdown]
# # Задача 7
# Написать функцию, принимающая целое число n, задающее количество кубиков. Функция
# должна определить, можно ли из данного кол-ва кубиков построить пирамиду, то есть
# можно ли представить число n как 1^2+2^2+3^2+…+k^2. Если можно, то функция должна
# вернуть k, иначе строку “It is impossible”. Написать тесты для кода

# %%
def pyramid(number):
    num = 1
    k = 2
    while number >= num:
        num += k ** 2
        k += 1
    else:
        if number == (num - (k-1)**2):
            return k - 2
        else:
            return 'It is impossible'
test_list = [
    1 + 2*2 + 3**2 + 4**2 + 5**2,
    2,
    6,
    18,
    1 + 2*2 + 3**2 + 4**2 + 5**2 + 6**2 + 7**2
]
for i in test_list:
    print(pyramid(i), i)
# Out:
# 5 55
# It is impossible 2
# It is impossible 6
# It is impossible 18
# 7 140

# %% [markdown]
# # Задача 8
# Функция принимает на вход положительное число и определяет является ли оно сбалансированным, т.е. сумма цифр до средних равна сумме цифр после. Средними в случае нечетного числа цифр считать одну цифру, в случае четного - две средних. Написать тесты для кода

# %%
def func8(n):
    n = str(n)
    if len(n)%2 == 0:
        left_ind = len(n)//2-1
        right_ind = len(n)//2 + 1
        left_sum = sum(map(int, n[:left_ind]))
        right_sum = sum(map(int, n[right_ind:]))
        return right_sum  == left_sum
    else:
        ind = len(n)//2
        left_sum = sum(map(int, n[:ind]))
        right_sum = sum(map(int, n[ind + 1:]))
        return right_sum  == left_sum
test_list = [
    '11211',
    '112211',
    '1' * 1000 + '2' + '1' * 1000,
    '1' * 1000 + '22' + '1' * 1000,
    '65736573657650235067' * 1000
]
for i in test_list:
    print(func8(i))
# Out:
# True
# True
# True
# True
# False
